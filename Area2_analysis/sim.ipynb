# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from lr_funcs import calc_proj
import random

# %%
N = 100
D = np.random.normal(0, 1, 3*N).reshape(3,N)

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(projection='3d')
ax.scatter(D[0,:], D[1,:],D[2,:], color='gray')
ax.grid(False)
# plt.axis('off')
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.set_xlim([-2.5, 2.5])
ax.set_ylim([-2.5, 2.5])
ax.set_zlim([-2.5, 2.5])
vector_1 = np.random.normal(0, 1, 3)
ax.quiver(0,0,0,vector_1_large[0],vector_1_large[1],vector_1_large[2],color = 'green',zorder=10)
plt.tight_layout()
plt.savefig('cloud_0.pdf', dpi = 'figure')

# %%
# x = np.random.randn(3)
# x -= x.dot(x) * x
# x /= np.linalg.norm(x)
# vector_2 = np.cross(vector_1_large, x)  

D_ = calc_proj(D.T, vector_1_large[:,np.newaxis])
D_sub = D - D_
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(projection='3d')
ax.scatter(D_sub[0,:], D_sub[1,:],D_sub[2,:], color='gray')
ax.grid(False)
# plt.axis('off')
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.set_xlim([-2.5, 2.5])
ax.set_ylim([-2.5, 2.5])
ax.set_zlim([-2.5, 2.5])
ax.quiver(0,0,0,vector_1_large[0],vector_1_large[1],vector_1_large[2],color = 'green',zorder=10)
ax.quiver(0,0,0,vector_2[0],vector_2[1],vector_2[2],color = 'magenta',zorder=10)
plt.tight_layout()

plt.savefig('cloud_1.pdf', dpi = 'figure')

# %%
D_ = calc_proj(D.T, vector_1_large[:,np.newaxis])
D_sub = D - D_
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(D_sub[0,:], D_sub[1,:],D_sub[2,:], color='gray')
ax.grid(False)
# plt.axis('off')
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.set_xlim([-2.5, 2.5])
ax.set_ylim([-2.5, 2.5])
ax.set_zlim([-2.5, 2.5])
ax.quiver(0,0,0,vector_1_large[0],vector_1_large[1],vector_1_large[2],color = 'green',zorder=10)
ax.quiver(0,0,0,vector_2[0],vector_2[1],vector_2[2],color = 'magenta',zorder=10)
plt.savefig('cloud_1.pdf', dpi = 'figure')

# %%
import papermill as pm
import os   
template_nb = "area2_auto_integrate.ipynb"  
os.makedirs("outputs", exist_ok=True)

monkeys = [
    "Han_20171207",
    "Duncan_20190710",
    "Chips_20170913",
    "Lando_20170731",
    # "Han_20171201",
    # "Han_20171204",
    # "Duncan_20191016",
    # "Duncan_20191106",
    "Lando_20170803",
]

for monkey in monkeys:
    out_nb = f"outputs/{monkey}_actpas.ipynb"
    print("Hello from:", monkey, "->", out_nb)

    try:
        pm.execute_notebook(
            template_nb,
            out_nb,
            parameters={"monkey": monkey},
            kernel_name="sdt_env",     
        )
        print("Finished:", out_nb)
    except Exception as e:
        print("FAILED:", monkey,e)
        continue
# Out:
# Hello from: Han_20171207 -> outputs/Han_20171207_actpas.ipynb
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# 2025-12-19 12:53:41.810485: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Finished: outputs/Han_20171207_actpas.ipynb
# Hello from: Duncan_20190710 -> outputs/Duncan_20190710_actpas.ipynb
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# 2025-12-19 14:04:23.349299: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Finished: outputs/Duncan_20190710_actpas.ipynb
# Hello from: Chips_20170913 -> outputs/Chips_20170913_actpas.ipynb
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# 2025-12-19 17:26:34.934165: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Finished: outputs/Chips_20170913_actpas.ipynb
# Hello from: Lando_20170731 -> outputs/Lando_20170731_actpas.ipynb
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# 2025-12-19 19:23:22.144536: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Finished: outputs/Lando_20170731_actpas.ipynb
# Hello from: Lando_20170803 -> outputs/Lando_20170803_actpas.ipynb
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# 2025-12-19 20:36:53.359116: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Finished: outputs/Lando_20170803_actpas.ipynb
